# %%
import numpy as np
import pandas as pd

# %% [markdown]
# creation of DataFrames using dict

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
df = pd.DataFrame(data)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# create a dataframe using list

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
columns=['Name','age','City','Salary']
pd.DataFrame(data_list,columns=columns)
# Out:
#     Name  age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# selection of column

# %%
df["Name"]
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: object

# %%
df[["Name","City"]]
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %% [markdown]
# create a new column

# %%
df["designation"] = ["doc","engineer","gynac","coder"]
df
# Out:
#     Name  Age      City  Salary designation
# 0   John   28  New York   65000         doc
# 1   Anna   34     Paris   70000    engineer
# 2  Peter   29    Berlin   62000       gynac
# 3  Linda   42    London   85000       coder

# %% [markdown]
# drop a column

# %%
df.drop(["designation","Salary"] , axis=1 ,inplace=True)

# %%
df
# Out:
#     Name  Age      City
# 0   John   28  New York
# 1   Anna   34     Paris
# 2  Peter   29    Berlin
# 3  Linda   42    London

# %% [markdown]
# drop a row

# %%
df.drop(0,axis=0,inplace=True)
df
# Out:
#     Name  Age    City
# 1   Anna   34   Paris
# 2  Peter   29  Berlin
# 3  Linda   42  London

# %% [markdown]
# Selection of rows

# %%
df.loc[1]
# Out:
# Name     Anna
# Age        34
# City    Paris
# Name: 1, dtype: object

# %%
df.loc[[1,2]]
# Out:
#     Name  Age    City
# 1   Anna   34   Paris
# 2  Peter   29  Berlin

# %%
df.iloc[0]
# Out:
# Name     Anna
# Age        34
# City    Paris
# Name: 1, dtype: object

# %% [markdown]
# slicing rows and cols

# %%
df.loc[[1,2]][["Name","City"]]
# Out:
#     Name    City
# 1   Anna   Paris
# 2  Peter  Berlin

# %%
df.loc[[1,2,3]][["Name","City"]]
# Out:
#     Name    City
# 1   Anna   Paris
# 2  Peter  Berlin
# 3  Linda  London

# %% [markdown]
# conditional selection

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
df = pd.DataFrame(data)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#see elements above age is 30 
df[df["Age"] > 30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
#age above 30 and city must be paris
